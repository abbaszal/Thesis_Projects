# %%
from hist import plot_nash_equilibrium_histogram

# %% [markdown]
# ### Histogram For FedLR & FedFor in HuGaDB with Different subsample & maxiter

# %%
# Set the directory containing your files
directory = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedLR_HuGa_Nash_Check"  
# Regular expression to match file pattern (subsample & maxiter or max_depth are variable)
file_pattern = r"Nash_Equilibrium_Counts_HuGaLR_subsample_(\d+\.?\d*)_maxiter_(\d+)"

# %% [markdown]
# ### 80 Trials in total

# %%
plot_nash_equilibrium_histogram(directory, file_pattern, "FedLR_huGa")

# %%
directory = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedFor_HuGa_Nash_Check"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaFedFor_subsample_(\d+\.?\d*)_max_depth_(\d+)"

# %% [markdown]
# ### 60 Trials in total

# %%
plot_nash_equilibrium_histogram(directory, file_pattern, "FedFor_huGa")

# %% [markdown]
# ### Histogram For FedLR & FedFor in Spambase with Different maxiter

# %%
directory = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedLR_Spambase_Nash_Check"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseLR_maxiter_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory, file_pattern, "FedLR_Spambase")

# %%
directory = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedFor_Spambase_Nash_Check"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseFedFor_max_depth_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory, file_pattern, "FedFor_Spambase")
