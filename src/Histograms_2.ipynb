# %%
from hist import plot_nash_equilibrium_histogram

# %% [markdown]
# ### Histogram For FedLR in HuGaDB with Different number of Corrupted Clients and Different subsample & maxiter

# %%
# Set the directory containing your files
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedLR/3_Corrupted_Clients"  
# Regular expression to match file pattern (subsample & maxiter or max_depth are variable)
file_pattern = r"Nash_Equilibrium_Counts_HuGaLR_subsample_(\d+\.?\d*)_maxiter_(\d+)"

# %% [markdown]
# ### 80 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_HuGa_3_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedLR/4_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaLR_subsample_(\d+\.?\d*)_maxiter_(\d+)"

# %% [markdown]
# ### 80 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_HuGa_4_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedLR/6_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaLR_subsample_(\d+\.?\d*)_maxiter_(\d+)"

# %% [markdown]
# ### 80 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_HuGa_6_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedLR/8_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaLR_subsample_(\d+\.?\d*)_maxiter_(\d+)"

# %% [markdown]
# ### 80 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_HuGa_8_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedLR/9_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaLR_subsample_(\d+\.?\d*)_maxiter_(\d+)"

# %% [markdown]
# ### 80 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_HuGa_9_Corrupted')

# %% [markdown]
# ### Histogram For FedFor in HuGaDB with Different number of Corrupted Clients and Different subsample & max_depth

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedFor/3_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaFedFor_subsample_(\d+\.?\d*)_max_depth_(\d+)"

# %% [markdown]
# ### 40 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_HuGa_3_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedFor/4_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaFedFor_subsample_(\d+\.?\d*)_max_depth_(\d+)"

# %% [markdown]
# ### 40 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_HuGa_4_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedFor/6_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaFedFor_subsample_(\d+\.?\d*)_max_depth_(\d+)"

# %% [markdown]
# ### 40 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_HuGa_6_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedFor/8_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaFedFor_subsample_(\d+\.?\d*)_max_depth_(\d+)"

# %% [markdown]
# ### 40 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_HuGa_8_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_HuGa_Nash_Check/FedFor/9_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_HuGaFedFor_subsample_(\d+\.?\d*)_max_depth_(\d+)"

# %% [markdown]
# ### 40 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_HuGa_9_Corrupted')
