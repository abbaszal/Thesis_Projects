# %% [markdown]
# ### The green label represents the best client across all trials, while the red labels indicate the four worst-performing clients

# %%
from utils.Heatmap import analyze_client_occurrences

# %% [markdown]
# ### 80 Trials in total

# %%
file_path = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedLR_HuGa_Nash_Check/Nash_Equilibrium_Details_HuGaLR.csv"
analyze_client_occurrences(file_path, 1, 4, "FedLR_HuGa" , plot_worst_only=False)

# %% [markdown]
# ### 60 Trials in total

# %%
file_path = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedFor_HuGa_Nash_Check/Nash_Equilibrium_Details_HuGaFedFor.csv"
analyze_client_occurrences(file_path, 1, 4, "FedFor_HuGa" , plot_worst_only=False)

# %% [markdown]
# ### 20 Trials in total

# %%
file_path = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedLR_Spambase_Nash_Check/Nash_Equilibrium_Details_SpambaseLR.csv"
analyze_client_occurrences(file_path, 1, 4, "FedLR_Spambase" , plot_worst_only=False)

# %% [markdown]
# ### 20 Trials in total

# %%
file_path = "/Users/abbaszal/Documents/Thesis_Project_Spambase/results/FedFor_Spambase_Nash_Check/Nash_Equilibrium_Details_SpambaseFedFor.csv"
analyze_client_occurrences(file_path, 1, 4, "FedFor_Spambase" , plot_worst_only=False)
