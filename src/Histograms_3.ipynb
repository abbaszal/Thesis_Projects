# %%
from hist import plot_nash_equilibrium_histogram

# %% [markdown]
# ### Histogram For FedLR in Spambase with Different number of Corrupted Clients and Different maxiter

# %%
# Set the directory containing your files
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedLR/3_Corrupted_Clients"  
# Regular expression to match file pattern (subsample & maxiter or max_depth are variable)
file_pattern = r"Nash_Equilibrium_Counts_SpambaseLR_maxiter_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_Spambase_3_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedLR/4_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseLR_maxiter_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_Spambase_4_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedLR/6_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseLR_maxiter_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_Spambase_6_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedLR/8_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseLR_maxiter_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_Spambase_8_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedLR/9_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseLR_maxiter_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedLR_Spambase_9_Corrupted')

# %% [markdown]
# ### Histogram For FedFor in Spambase with Different number of Corrupted Clients and Different max_depth

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedFor/3_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseFedFor_max_depth_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_Spambase_3_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedFor/4_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseFedFor_max_depth_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_Spambase_4_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedFor/6_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseFedFor_max_depth_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_Spambase_6_Corrupted')

# %%
directory = "/.../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedFor/8_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseFedFor_max_depth_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_Spambase_8_Corrupted')

# %%
directory = ".../results/fedLR_FedFor__with_Corrupting_Spambase_Nash_Check/FedFor/9_Corrupted_Clients"  
file_pattern = r"Nash_Equilibrium_Counts_SpambaseFedFor_max_depth_(\d+)"

# %% [markdown]
# ### 20 Trials in total

# %%
plot_nash_equilibrium_histogram(directory,file_pattern,title_suffix='FedFor_Spambase_9_Corrupted')
